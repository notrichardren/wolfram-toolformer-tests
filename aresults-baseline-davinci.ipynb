# %% [markdown]
# This notebook:
# 1. Takes testing problems from /test/MATH.
# 1. Runs function "answer" on them, which **calls DaVinci GPT-3**.
# 1. Saves the result in **results-baseline-davinci** under "gpt-answer".

# %%
import os
import json
import openai

with open('keys.json') as f:
    data = json.load(f)
openai.api_key = data['openai-key']

# %%
# Test code block: run this to test the writing/reading of the modified data works, before you call GPT-3 API and potentially waste credits
def answer(problem):
    return "We answered " + problem

# %%
with open('prompts.json') as f:
    data = json.load(f)
prompt_json = data['no_wolfram']

# Calls DaVinci GPT-3 API on input text & returns output.
def answer(problem):

    full_message = "[Problem] " + problem + "\n\n" + prompt_json
    
    # Use the OpenAI API to generate a response
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=full_message,
        temperature=0, # temperature 0 keeps it deterministic
        max_tokens = 600
    )

    text_output = response["choices"][0]["text"]
    print(text_output)
    return text_output

# %%
# Test code block: run this to test that davinci works, before you call GPT-3 API and potentially waste credits. Will print twice.
answer("What is 4+5?")
# Out:
# \boxed{9}
# '\n\n\\boxed{9}'

# %%
# Define the paths to the data directories
data_dir = "test/MATH"
modified_data_dir = "results-baseline-davinci/MATH"

# Loop over the directories | possible: ["train", "test"]:
for data_type in ["test"]:
    # Loop over the subdirectories in the data directory
    for sub_dir in os.listdir(os.path.join(data_dir, data_type)):
        
        # Skip any files that are not directories
        if not os.path.isdir(os.path.join(data_dir, data_type, sub_dir)):
            continue
        
        # Create the corresponding subdirectory in the modified data directory
        os.makedirs(os.path.join(modified_data_dir, data_type, sub_dir), exist_ok=True)

        # Get a list of all the JSON files in the original subdirectory
        json_files = [f for f in os.listdir(os.path.join(data_dir, "test", sub_dir)) if f.endswith(".json")]
        
        # Loop over the selected JSON files in the original subdirectory
        for file_name in json_files:
            
            # Load the JSON file
            with open(os.path.join(data_dir, data_type, sub_dir, file_name), "r") as file:
                data = json.load(file)
            
            # Extract the problem field
            problem = data["problem"]
            
            # Call the answer function
            answer_text = answer(problem)
            
            # Add the answer field to the JSON data
            data["gptanswer"] = answer_text
            
            # Save the modified JSON data to a new file
            with open(os.path.join(modified_data_dir, data_type, sub_dir, file_name), "w") as file:
                json.dump(data, file)
# Out:
# \boxed{n}
#
#
# Answer: $\boxed{15}$
#
#
# \boxed{10}
#
#
# \boxed{30}
#
#
# \boxed{5}
#
#
# \boxed{462}
#
#
# \$1
#
#
# \boxed{15}
#
#
# \boxed{4}
#
#
# Answer: $\frac{10}{11}$
#
#
# \boxed{504}
#
#
# \boxed{3/4}
#
#
# \boxed{11}
#
#
# \boxed{1/625}
#
#
# \boxed{21}
#
#
# \boxed{\dbinom{n}{0} = 1}
#
#
# \boxed{1}
#
#
# \boxed{10}
#
#
# Answer: $\frac{3}{4}$
#
#
# \boxed{8 \choose 4}
#
#
# \boxed{10080}
#
#
# \boxed{P(3 \leq X \leq 11) = \frac{9}{36}}
#
#
# \boxed{99}
#
#
# \boxed{5}
#
#
# \boxed{0}
#
#
# \boxed{0}
#
#
# \boxed{13 \choose 15}
#
#
# \boxed{84}
#
#
# \boxed{135}
#
#
# \boxed{50 \times 51 \div 2 = 1275}
#
#
# $\boxed{2}$
#
#
# \boxed{-3,2}
#
#
# \boxed{\left[2,\infty\right)}
#
#
# \boxed{24}
#
#
# \boxed{-15}
#
#
# \boxed{|w| = \frac{4}{\sqrt{50}}}
#
#
# \boxed{120}
#
#
# \boxed{-4, 1, 0, 4}
#
#
# \boxed{a+2b+3c+4d = 0}
#
#
# \boxed{x = -3}
#
#
# \boxed{-3}
#
#
# \boxed{x^5 - 2x^4 + x^3 - 2x^2 + x - 3}
#
#
# \boxed{-\frac{17}{2}}
#
#
# $$1,841$$
#
#
# \boxed{a+b=2}
#
#
# \boxed{50}
#
#
# \boxed{2\sqrt{7} + 1}
#
#
# \boxed{24^{\frac{1}{7}}}
#
#
# \boxed{-1}
#
#
# \boxed{10}
#
#
# \boxed{Ellipse}
#
#
# \boxed{|5-12i| = 13}
#
#
# \boxed{a = -3}
#
#
# \boxed{[-13, -1]}
#
#
# \boxed{7\sqrt{2}}
#
#
# \boxed{r^2+s^2+t^2 = -\frac{1}{2}}
#
#
# \textbf{Odd}
#
#
# \boxed{7x(x-3)(x-2)}
#
#
# \boxed{(4, -2)}
#
#
# \boxed{x^2 + (a + b + c)x + ab + bc + ca}
#
#
# \boxed{60}
#
#
# \boxed{1326}
#
#
# \boxed{3}
#
#
# \boxed{125_7}
#
#
# \boxed{0}
#
#
# \boxed{2}
#
#
# \textbf{M}
#
#
# \boxed{17}
#
#
# \boxed{97}
#
#
# \boxed{555_5 = \underline{44444}}
#
#
# \boxed{169}
#
#
# \boxed{999}
#
#
# \boxed{10595}
#
#
# \boxed{9}
#
#
# \boxed{240}
#
#
# \boxed{20}
#
#
# \boxed{2}
#
#
# \boxed{7}
#
#
# \boxed{144}
#
#
# \boxed{Monday}
#
#
# \boxed{2}
#
#
# \boxed{2}
#
#
# \boxed{3}
#
#
# \boxed{6}
#
#
# \boxed{n = 39483}
#
#
# \boxed{49}
#
#
# \boxed{45}
#
#
# \boxed{1111_2}
#
#
# \boxed{4}
#
#
# \boxed{\frac{7}{8}}
#
#
# \boxed{\begin{pmatrix} 2 & 7 \\ 13 & -2 \end{pmatrix}}
#
#
# \boxed{(-7, -2)}
#
#
# \boxed{-\frac{1}{4}}
#
#
# \boxed{-13}
#
#
# \boxed{n = -42^\circ}
#
#
# \boxed{n = 1021}
#
#
# \boxed{\frac{7}{12}}
#
#
# \boxed{-5}
#
#
# \boxed{\cos (a - b) = -\frac{1}{2}}
#
#
# \boxed{-7}
#
#
# \boxed{\cos(\alpha - \beta) = \frac{-1}{2}}
#
#
# \boxed{\tan 15^\circ = 0.2679}
#
#
# \boxed{(-2, 5, -1)}
#
#
# $|(4+2i)|\cdot|(6-3i)| = 10$
#
#
# \boxed{AD = 3\sqrt{3}}
#
#
# \boxed{1}
#
#
# \boxed{\sin 2\theta = \frac{2\sqrt{2}}{3}}
#
#
# \boxed{-\frac{1}{2}}
#
#
# \boxed{-22}
#
#
# \boxed{3}
#
#
# \boxed{5}
#
#
# \boxed{2.5}
#
#
# \boxed{-2, -1, 4}
#
#
# \boxed{(7.07, 5.00)}
#
#
# \boxed{DE = 5}
#
#
# \boxed{-5\sqrt{2} + \sqrt{2}i}
#
#
# \boxed{17}
#
#
# \boxed{-2(a^2b + ab^2 + ac^2 - bc^2 - b^2c - c^2a)}
#
#
# \boxed{\tan 135^\circ = -1}
#
#
# \boxed{a = 4, \quad c = -6, \quad d = 34}
#
#
# \boxed{97}
#
#
# \boxed{999}
#
#
# \boxed{563}
#
#
# \boxed{1^{2^{235423523}}}
#
#
# \boxed{10}
#
#
# \boxed{k = 8}
#
#
# \boxed{2004}
#
#
# \boxed{11.2}
#
#
# \boxed{5}
#
#
# \boxed{5}
#
#
# \boxed{\frac{1}{2 + \frac{1}{3} + \frac{1}{4}}}
#
#
# \boxed{490}
#
#
# \boxed{95914041}
#
#
# \boxed{2}
#
#
# \boxed{\frac{3}{4}}
#
#
# \frac{1}{4}
#
#
# \boxed{1/100}
#
#
# \boxed{9}
#
#
# \boxed{576}
#
#
# $$\frac{7+21}{14+42} = \frac{28}{56} = \frac{1}{2}$$
#
#
# \boxed{50^\circ}
#
#
# \boxed{5}
#
#
# \boxed{3}
#
#
# \boxed{-\frac{40}{153}}
#
#
# \boxed{7!}
#
#
# \boxed{80}
#
#
# \boxed{21}
#
#
# \boxed{17}
#
#
# \boxed{-2}
#
#
# \boxed{8}
#
#
# \boxed{180^{\circ}}
#
#
# \boxed{135^{\circ}}
#
#
# \boxed{\pi \cdot 5^2}
#
#
# \boxed{12}
#
#
# \boxed{50^{\circ}}
#
#
# Answer: \boxed{64}
#
#
# \boxed{\sin B = \frac{5}{8}}
#
#
# \boxed{4}
#
#
# \boxed{\cos 60^\circ = \frac{1}{2}}
#
#
# \boxed{12}
#
#
# \boxed{20 \pi}
#
#
# \boxed{2}
#
#
# \boxed{36}
#
#
# \boxed{100^\circ}
#
#
# \boxed{11}
#
#
# \boxed{144 \text{ cm}^2}
#
#
# \boxed{105^{\circ}}
#
#
# \boxed{90^{\circ}}
#
#
# \boxed{9}
#
#
# \boxed{360^{\circ}}
#
#
# \boxed{54 \text{ in}^2}
#
#
# \boxed{r = \frac{10\pi}{75^{\circ}}}
#
#
# \boxed{\cos 300^\circ = -\frac{1}{2}}
#
#
# \boxed{16 \text{ cm}^2}
#
#
# \boxed{AX = 10.04}
#
#
# $a+b = 7$
#
#
# \boxed{150}
#
#
# Answer: $\boxed{55^\circ}$
#
#
# \boxed{x = \frac{v+z}{2}}
#
#
# \boxed{27 \text{ cm}^3}
#
#
# \boxed{12 \cdot 10 = 120}
#
#
# \boxed{AC^2 - B = 8}
#
#
# \boxed{ \frac{7}{45^2 - 38^2} = \frac{7}{441} }
#
#
# \boxed{d = 12}
#
#
# \boxed{10}
#
#
# \boxed{24}
#
#
# \boxed{20}
#
#
# \boxed{5}
#
#
# \boxed{5}
#
#
# \boxed{p+q = 11}
#
#
# \boxed{144}
#
#
# $\boxed{10r^9}$
#
#
# \boxed{A+B+C = 18}
#
#
# \boxed{2}
#
#
# \boxed{a = -8}
#
#
# \boxed{91^2 = 8281}
#
#
# \boxed{-20}
#
#
# \boxed{17}
#
#
# \boxed{115^2 = 13225}
#
#
# \boxed{108\ \text{m}}
#
#
# \boxed{10000}
#
#
# \boxed{p = 196}
#
#
# \boxed{x^2 + 10x + 25}
#
#
# \boxed{81}
#
#
# \boxed{97.6}
#
#
# \boxed{c = 81}
#
#
# \boxed{(x+1)^3 \cdot x}
#
#
# \boxed{640}
#
#
# \boxed{-\sqrt{\frac{5}{2}}}
#
#
# \boxed{105}
